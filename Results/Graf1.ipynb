# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

Change_m = []
Change_m1 = []
Change_n = []
Change_n1 = []
Change_k = []
Change_k1 = []
My_ticks = []
My_ticks1 = []
i = 0
k = 0

with open ("/home/artem/Elbrus/Res/result_K_1.csv", 'r') as fileK:
    for line in fileK:
        Change_k1.append(float(line.strip()))
        k = k + 1
        My_ticks.append(k * 48)
fileK.close()
#print (My_ticks)
#j = 1
#for j in range (0, len(Change_k1), 3):
    #Change_k.append((Change_k1[j] + Change_k1[j + 1] + Change_k1 [j + 2]) / 3)
#print (len(Change_k))
#k = int (k / 3)
print (Change_k1)
del My_ticks[k:len(My_ticks)]

with open ("/home/artem/Elbrus/Res/result_N_1.csv", 'r') as fileN:
    for line in fileN:
        Change_n1.append(float(line.strip()))
print (Change_n)
fileN.close()


#j = 1
#for j in range (0, len(Change_n1), 3):
    #Change_n.append((Change_n1[j] + Change_n1[j + 1] + Change_n1 [j + 2]) / 3)
print (len(Change_n))

with open ("/home/artem/Elbrus/Res/result_M_1.csv", 'r') as fileM:
    for line in fileM:
        Change_m1.append(float(line.strip()))
#print (Change_m)
fileM.close()


#j = 1
#for j in range (0, len(Change_m1), 3):
    #Change_m.append((Change_m1[j] + Change_m1[j + 1] + Change_m1 [j + 2]) / 3)
#print (len(Change_m))

fig , ax = plt.subplots(figsize = (20, 10))

plt.plot(My_ticks,Change_k1,'b', label = 'k')
plt.plot(My_ticks,Change_n1,'g', label = 'n')
plt.plot(My_ticks,Change_m1,'r', label = 'm')
plt.legend()

plt.xlim([0, k*48])
ax.xaxis.set_major_locator(ticker.MultipleLocator(512))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(1024))

ax.yaxis.set_major_locator(ticker.MultipleLocator(100))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(50))

plt.grid()
plt.title("Зависимость производительности от размеров матриц M, N, K")
plt.xlabel("Количество элементов по M, N, K x16")
plt.ylabel("Производительность %")
# Out:
# [9.21227, 20.6092, 29.8323, 41.9886, 50.1957, 61.5455, 71.1087, 75.2623, 90.3147, 108.678, 109.724, 135.33, 110.442, 140.373, 146.508, 161.112, 170.135, 175.721, 195.164, 201.579, 214.748, 192.208, 236.477, 195.456, 245.945, 268.981, 278.819, 277.01, 289.242, 284.672, 286.153, 306.692, 336.287, 322.882, 344.604, 348.345, 350.373, 364.667, 389.987, 406.165, 405.455, 398.894, 420.33, 412.417, 328.225, 332.856, 464.362, 422.11, 471.211, 471.537, 452.61, 502.36, 390.258, 526.1, 531.981, 501.265, 522.807, 523.825, 423.091, 583.79, 422.812, 545.424, 573.269, 614.664, 584.587, 631.738, 456.702, 606.544, 651.039, 630.201, 567.981, 618.036, 664.264, 638.778, 628.6, 505.36, 651.522, 662.885, 711.028, 535.532, 696.342, 742.593, 763.091, 516.643, 680.484, 790.974, 566.269, 720.01, 780.885, 703.894, 744.24, 744.293, 759.826, 495.276, 573.602, 605.636, 824.357, 787.559, 636.614, 769.034, 850.201, 837.535, 884.135, 860.096, 787.8, 858.418, 917.818, 740.354, 641.616, 644.401, 816.835, 821.255, 909.9
# ...
